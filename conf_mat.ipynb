# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# %%
array=[[    0  ,   0 ,    0 ,    0,     0,     0 ,    0 ,    0 ,10743 ,    0 ,    0],
 [    0,     0,     0,     3,     0,     0,     1,     0,  5933,     0,     0],
 [    0 ,   23 ,    0 , 1879 ,    0 ,    0 ,    6 ,    0 , 3635 ,    0 ,    0],
 [    0  ,   1  ,   0, 18881  ,   0  ,   0  ,   0  ,   0  ,  17  ,   0  ,   0],
 [    0    , 0   ,  0 ,20931   ,  0   ,  0   ,  0   ,  0   , 19   ,  0   ,  1],
 [    0   ,306    , 0  ,2947    , 0    , 0    , 0    , 0, 19472    , 0    , 0],
 [    0,     0     ,0,  8566     ,0     ,0     ,0     ,0 ,   54     ,0     ,0],
 [    0 ,    0,     0 , 5363,     0 ,    0,     0,     0, 18129,     0,     0],
 [    0  , 533 ,    0  ,4777 ,    0  ,   0 ,    0 ,    0 ,24960 ,    0 ,    0],
 [    0   ,121  ,   0 , 2298  ,   0   ,  0  ,   0  ,   0, 14937  ,   0  ,   0],
 [    0    , 4   ,  1  ,   3   ,  2    , 0   ,710   ,  0 , 1608   ,  4   ,308]]

# %%
att_names=["gafgyt_combo","gafgyt_junk","gafgyt_scan","gafgyt_tcp","gafgyt_udp","mirai_ack","mirai_scan","mirai_syn","mirai_udp","mirai_udpplain","benign"]
df_cm = pd.DataFrame(array, index = [i for i in att_names],
              columns = [i for i in att_names])
plt.figure(figsize = (12,7))
sn.heatmap(df_cm, annot=True,cmap="Greens_r")
# Out:
# <Axes: >
